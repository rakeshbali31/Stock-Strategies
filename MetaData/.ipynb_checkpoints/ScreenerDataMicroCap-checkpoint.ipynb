# %%
import requests
import csv
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Function to extract and store data from a page
def extract_data(url, headers, writer):
    response = requests.get(url, headers=headers)
    if response.ok:
        soup = BeautifulSoup(response.text, 'html.parser')
        table = soup.find('table', class_='data-table')
        rows = table.find_all('tr')
        for row in rows[1:]:  # Skipping header row
            cols = row.find_all('td')
            symbol = str(cols[1].find('a')).split('/')[2]
            data = [col.text.strip() for col in cols]
            data.append(symbol)
            writer.writerow(data)

# URL of the website
base_url = 'https://www.screener.in/screens/1597692/screenerdata/?page='

# Session ID and CSRF token obtained from somewhere (e.g., through authentication)
session_id = 'gxja81spl0xn0hggiwu4g5kxmhnbv9mz'
csrf_token = '8uCAl5uBfrOlzD295ykL6XYQ6BNEPwQU'

# Construct headers with session ID and CSRF token
headers = {
    'Cookie': f'sessionid={session_id}',  # Assuming the session ID is passed via cookie
    'X-CSRFToken': csrf_token  # Assuming the CSRF token is passed in a header
}

# CSV file to store the data
csv_filename = 'screener_data.csv'
fieldnames = ['S.No.', 'Name', 'CMP Rs.', 'P/E', 'Mar Cap Rs.Cr.', 'Qtr Sales Var %', 'Qtr Profit Var %', 
              'QoQ Sales %', 'QoQ Profits %', 'Prom. Hold. %', 'DII Hold %', 'FII Hold %', 'Exp Qtr Sales Var %',
              'RSI Rs.', 'MACD Signal Rs.', 'Change in Prom Hold %', 'ROCE', 'SYMBOL']

with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(fieldnames)
    for page_num in range(1, 161):  # Iterate over pages 1 to 30
        url = base_url + str(page_num) + '&limit=10'
        try:
            extract_data(url, headers, writer)
            print(f"Data from page {page_num} extracted and stored.")
        except Exception as e:
            print(f"Failed to extract data from page {page_num}. Error: {e}")

print("All data extracted and stored in", csv_filename)
# Out:
# Failed to extract data from page 1. Error: list index out of range
# Failed to extract data from page 2. Error: list index out of range
# Failed to extract data from page 3. Error: list index out of range
# Failed to extract data from page 4. Error: list index out of range
# Failed to extract data from page 5. Error: list index out of range
# Failed to extract data from page 6. Error: list index out of range
# Failed to extract data from page 7. Error: list index out of range
# Failed to extract data from page 8. Error: list index out of range
# Failed to extract data from page 9. Error: list index out of range
# Failed to extract data from page 10. Error: list index out of range
# Failed to extract data from page 11. Error: list index out of range
# Failed to extract data from page 12. Error: list index out of range
# Failed to extract data from page 13. Error: list index out of range
# Failed to extract data from page 14. Error: list index out of range
# Failed to extract data from page 15. Error: list index out of range
# Failed to extract data from page 16. Error: list index out of range
# Failed to extract data from page 17. Error: list index out of range
# Failed to extract data from page 18. Error: list index out of range
# Failed to extract data from page 19. Error: list index out of range
# Failed to extract data from page 20. Error: list index out of range
# Failed to extract data from page 21. Error: list index out of range
# Failed to extract data from page 22. Error: list index out of range
# Failed to extract data from page 23. Error: list index out of range
# Failed to extract data from page 24. Error: list index out of range
# Failed to extract data from page 25. Error: list index out of range
# Failed to extract data from page 26. Error: list index out of range
# Failed to extract data from page 27. Error: list index out of range
# Failed to extract data from page 28. Error: list index out of range
# Failed to extract data from page 29. Error: list index out of range
# Failed to extract data from page 30. Error: list index out of range
# Failed to extract data from page 31. Error: list index out of range
# Failed to extract data from page 32. Error: list index out of range
# Failed to extract data from page 33. Error: list index out of range
# Failed to extract data from page 34. Error: list index out of range
# Failed to extract data from page 35. Error: list index out of range
# Failed to extract data from page 36. Error: list index out of range
# Failed to extract data from page 37. Error: list index out of range
# Failed to extract data from page 38. Error: list index out of range
# Failed to extract data from page 39. Error: list index out of range
# Failed to extract data from page 40. Error: list index out of range
# Failed to extract data from page 41. Error: list index out of range
# Failed to extract data from page 42. Error: list index out of range
# Failed to extract data from page 43. Error: list index out of range
# Failed to extract data from page 44. Error: list index out of range
# Failed to extract data from page 45. Error: list index out of range
# Failed to extract data from page 46. Error: list index out of range
# Failed to extract data from page 47. Error: list index out of range
# Failed to extract data from page 48. Error: list index out of range
# Failed to extract data from page 49. Error: list index out of range
# Failed to extract data from page 50. Error: list index out of range
# Failed to extract data from page 51. Error: list index out of range
# Failed to extract data from page 52. Error: list index out of range
# Failed to extract data from page 53. Error: list index out of range
# Failed to extract data from page 54. Error: list index out of range
# Failed to extract data from page 55. Error: list index out of range
# Failed to extract data from page 56. Error: list index out of range
# Failed to extract data from page 57. Error: list index out of range
# Failed to extract data from page 58. Error: list index out of range
# Failed to extract data from page 59. Error: list index out of range
# Failed to extract data from page 60. Error: list index out of range
# Failed to extract data from page 61. Error: list index out of range
# Failed to extract data from page 62. Error: list index out of range
# Failed to extract data from page 63. Error: list index out of range
# Failed to extract data from page 64. Error: list index out of range
# Failed to extract data from page 65. Error: list index out of range
# Failed to extract data from page 66. Error: list index out of range
# Failed to extract data from page 67. Error: list index out of range
# Failed to extract data from page 68. Error: list index out of range
# Failed to extract data from page 69. Error: list index out of range
# Failed to extract data from page 70. Error: list index out of range
# Failed to extract data from page 71. Error: list index out of range
# Failed to extract data from page 72. Error: list index out of range
# Failed to extract data from page 73. Error: list index out of range
# Failed to extract data from page 74. Error: list index out of range
# Failed to extract data from page 75. Error: list index out of range
# Failed to extract data from page 76. Error: list index out of range
# Failed to extract data from page 77. Error: list index out of range
# Failed to extract data from page 78. Error: list index out of range
# Failed to extract data from page 79. Error: list index out of range
# Failed to extract data from page 80. Error: list index out of range
# Failed to extract data from page 81. Error: list index out of range
# Failed to extract data from page 82. Error: list index out of range
# Failed to extract data from page 83. Error: list index out of range
# Failed to extract data from page 84. Error: list index out of range
# Failed to extract data from page 85. Error: list index out of range
# Failed to extract data from page 86. Error: list index out of range
# Failed to extract data from page 87. Error: list index out of range
# Failed to extract data from page 88. Error: list index out of range
# Failed to extract data from page 89. Error: list index out of range
# Failed to extract data from page 90. Error: list index out of range
# Failed to extract data from page 91. Error: list index out of range
# Failed to extract data from page 92. Error: list index out of range
# Failed to extract data from page 93. Error: list index out of range
# Failed to extract data from page 94. Error: list index out of range
# Failed to extract data from page 95. Error: list index out of range
# Failed to extract data from page 96. Error: list index out of range
# Failed to extract data from page 97. Error: list index out of range
# Failed to extract data from page 98. Error: list index out of range
# Failed to extract data from page 99. Error: list index out of range
# Failed to extract data from page 100. Error: list index out of range
# Failed to extract data from page 101. Error: list index out of range
# Failed to extract data from page 102. Error: list index out of range
# Failed to extract data from page 103. Error: list index out of range
# Failed to extract data from page 104. Error: list index out of range
# Failed to extract data from page 105. Error: list index out of range
# Failed to extract data from page 106. Error: list index out of range
# Failed to extract data from page 107. Error: list index out of range
# Failed to extract data from page 108. Error: list index out of range
# Failed to extract data from page 109. Error: list index out of range
# Failed to extract data from page 110. Error: list index out of range
# Failed to extract data from page 111. Error: list index out of range
# Failed to extract data from page 112. Error: list index out of range
# Failed to extract data from page 113. Error: list index out of range
# Failed to extract data from page 114. Error: list index out of range
# Failed to extract data from page 115. Error: list index out of range
# Failed to extract data from page 116. Error: list index out of range
# Failed to extract data from page 117. Error: list index out of range
# Failed to extract data from page 118. Error: list index out of range
# Failed to extract data from page 119. Error: list index out of range
# Failed to extract data from page 120. Error: list index out of range
# Failed to extract data from page 121. Error: list index out of range
# Failed to extract data from page 122. Error: list index out of range
# Failed to extract data from page 123. Error: list index out of range
# Failed to extract data from page 124. Error: list index out of range
# Failed to extract data from page 125. Error: list index out of range
# Failed to extract data from page 126. Error: list index out of range
# Failed to extract data from page 127. Error: list index out of range
# Failed to extract data from page 128. Error: list index out of range
# Failed to extract data from page 129. Error: list index out of range
# Failed to extract data from page 130. Error: list index out of range
# Failed to extract data from page 131. Error: list index out of range
# Failed to extract data from page 132. Error: list index out of range
# Failed to extract data from page 133. Error: list index out of range
# Failed to extract data from page 134. Error: list index out of range
# Failed to extract data from page 135. Error: list index out of range
# Failed to extract data from page 136. Error: list index out of range
# Failed to extract data from page 137. Error: list index out of range
# Failed to extract data from page 138. Error: list index out of range
# Failed to extract data from page 139. Error: list index out of range
# Failed to extract data from page 140. Error: list index out of range
# Failed to extract data from page 141. Error: list index out of range
# Failed to extract data from page 142. Error: list index out of range
# Failed to extract data from page 143. Error: list index out of range
# Failed to extract data from page 144. Error: list index out of range
# Failed to extract data from page 145. Error: list index out of range
# Failed to extract data from page 146. Error: list index out of range
# Failed to extract data from page 147. Error: list index out of range
# Failed to extract data from page 148. Error: list index out of range
# Failed to extract data from page 149. Error: list index out of range
# Failed to extract data from page 150. Error: list index out of range
# Failed to extract data from page 151. Error: list index out of range
# Failed to extract data from page 152. Error: list index out of range
# Failed to extract data from page 153. Error: list index out of range
# Failed to extract data from page 154. Error: list index out of range
# Failed to extract data from page 155. Error: list index out of range
# Failed to extract data from page 156. Error: list index out of range
# Failed to extract data from page 157. Error: list index out of range
# Failed to extract data from page 158. Error: list index out of range
# Failed to extract data from page 159. Error: list index out of range
# Failed to extract data from page 160. Error: list index out of range
# All data extracted and stored in screener_data.csv

# %%
stock_data = pd.read_csv('stock_data.csv')
screener_data = pd.read_csv('screener_data.csv')
merged_data = stock_data.merge(screener_data, on='SYMBOL', how='left')

# %%
merged_data.to_csv('stock_data.csv')
